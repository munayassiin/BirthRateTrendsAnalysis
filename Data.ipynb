# %% [markdown]
# # Exploring Trends in Birth Rates: Unveiling Declines in Major Locations Over the Past Decade

# %%
import pandas as pd

# Created different Series from Pandas based on information of Oslo University Hospital

Hospital1 = pd.Series(['Aker University Hospital', 'Oslo', 'Oslo University Hospital', 'Aker Hospital is one of the largest treatment centres at Oslo University Hospital with 930 employees divided into 138 beds, 12 operating theatres and a high outpatient service, as well as several reception functions. In addition, Aker helsearena is here with about 1200 employees from Oslo municipality, Sunnaas and OUS.'
                       , 22894000],  index= ['Hospital Name:', 'Major Location:', 'Main Campus:', 'Description:', 'Front Desk nr:'])
print(Hospital1)

Hospital2 = pd.Series(['Rikshospitalet', 'Oslo', 'Oslo University Hospital', 'Rikshospitalet has a long history behind it in various places in Oslo. Rikshospitalet at Ring 3 at Gaustad is now close to the University of Oslo. Todays buildings were put into use in 2000. In addition to patient care, there is a lot of teaching and research at Rikshospitalet.'
                       , 22070000],  index= ['Hospital Name:', 'Major Location:', 'Main Campus:', 'Description:', 'Front Desk nr:'])

print(Hospital2)

Hospital3 = pd.Series(['Ullevål University Hospital', 'Oslo', 'Oslo University Hospital', 'Ullevål Hospital covers a large area and has treatment within somatics, mental health and substance abuse/addiction. There are overview maps at each entrance to the hospital that show which buildings are located where and which units are located in which buildings.'
                       , 91502769],  index= ['Hospital Name:', 'Major Location:', 'Main Campus:', 'Description:', 'Front Desk nr:'])

print(Hospital3)
# Out:
# Hospital Name:                              Aker University Hospital
# Major Location:                                                 Oslo
# Main Campus:                                Oslo University Hospital
# Description:       Aker Hospital is one of the largest treatment ...
# Front Desk nr:                                              22894000
# dtype: object
# Hospital Name:                                        Rikshospitalet
# Major Location:                                                 Oslo
# Main Campus:                                Oslo University Hospital
# Description:       Rikshospitalet has a long history behind it in...
# Front Desk nr:                                              22070000
# dtype: object
# Hospital Name:                           Ullevål University Hospital
# Major Location:                                                 Oslo
# Main Campus:                                Oslo University Hospital
# ...

# %%
import pandas as pd

# Included 16 Series of 16 Hospitals from the link : https://en.wikipedia.org/wiki/List_of_hospitals_in_Norway. 

Major_Location = pd.Series({'Aker University Hospital':'OSLO',
             'Rikshospitalet':'OSLO',
             'Ullevål University Hospital': 'OSLO',
             'Bærum Hospital': 'BÆRUM',
             'Kirkenes Hospital': 'KIRKENES',
             'Hammerfest Hospital':'HAMMERFEST' ,
             'Røros Hospital': 'RÆROS',
             'Orkdal Hospital': 'ORKANGER',
             'St. Olavs University Hospital': 'TRONDHEIM',
             'Namsos Hospital': 'NAMSOS',
             'Levanger Hospital': 'LEVANGER',
             'Volda Hospital': 'VOLDA',
             'Ålesund Hospital': 'ÅLESUND',
             'Molde Hospital': 'MOLDE',
             'Kristiansund Hospital': 'KRISTIANSUND',
             'Elverum Hospital': 'ELVERUM'
              })

Main_Campus = pd.Series({'Aker University Hospital':'Oslo University Hospital',
             'Rikshospitalet': 'Oslo University Hospital',
             'Ullevål University Hospital': 'Oslo University Hospital',
             'Bærum Hospital': 'Vestre Viken Hospital',
             'Kirkenes Hospital': 'Finmark Hospital Trust' ,
             'Hammerfest Hospital': 'Finmark Hospital Trust',
             'Røros Hospital': 'St. Olavs Hospital Trust',
             'Orkdal Hospital': 'St. Olavs Hospital Trust',
             'St. Olavs University Hospital': 'St. Olavs Hospital Trust',
             'Namsos Hospital': 'Nord-Trøndelag Hospital Trust',
             'Levanger Hospital': 'Nord-Trøndelag Hospital Trust',
             'Volda Hospital': 'Møre og Romsdal Hospital Trust',
             'Ålesund Hospital': 'Møre og Romsdal Hospital Trust',
             'Molde Hospital': 'Møre og Romsdal Hospital Trust',
             'Kristiansund Hospital': 'Møre og Romsdal Hospital Trust',
             'Elverum Hospital': 'Innlandet Hospital Trust'})

Description = pd.Series({'Aker University Hospital': 'Aker Hospital is one of the largest treatment centres at Oslo University Hospital with 930 employees divided into 138 beds, 12 operating theatres and a high outpatient service, as well as several reception functions. In addition, Aker helsearena is here with about 1200 employees from Oslo municipality, Sunnaas and OUS.',
             'Rikshospitalet': 'Rikshospitalet has a long history behind it in various places in Oslo. Rikshospitalet at Ring 3 at Gaustad is now close to the University of Oslo. Todays buildings were put into use in 2000. In addition to patient care, there is a lot of teaching and research at Rikshospitalet.',
             'Ullevål University Hospital': 'Ullevål Hospital covers a large area and has treatment within somatics, mental health and substance abuse/addiction. There are overview maps at each entrance to the hospital that show which buildings are located where and which units are located in which buildings.',
             'Bærum Hospital': 'Bærum Hospital is a hospital located at Dønski in the municipality of Bærum. It is state-owned through Vestre Viken HF and has approximately 2,300 employees.',
             'Kirkenes Hospital': 'Kirkenes Hospital is located at Andrevann in Kirkenes and was new in 2018. The hospital has emergency function and is a local hospital for Eastern Finnmark.',
             'Hammerfest Hospital': 'Hammerfest sykehus ligger på Fuglenes i Hammerfest kommune, mellom Hammerfest sentrum og Hammerfest lufthavn. Sykehuset har akuttfunksjon, og er lokalsykehus for Vest-Finnmark.',
             'Røros Hospital': 'Røros Hospital is a department of central staff. Røros Hospital has a number of outpatient and surgical services. ',
             'Orkdal Hospital': 'Orkdal Hospital is part of St. Olavs Hospital. See overview of departments below. The hospital is also an out-of-hours clinic for 17 municipalities with a total population of almost 70,000.',
             'St. Olavs University Hospital': 'St. Olavs University Hospital (Norwegian: St. Olavs Hospital Universitetssykehuset i Trondheim) is the hospital in Trondheim, Norway located at Øya. It is part of St. Olavs Hospital Trust that operates all the hospitals in Sør-Trøndelag and thus indirectly state owned. It cooperates closely with the Norwegian University of Science and Technology in research and in education of medical doctors. The university is named for Olaf II of Norway, also known as St. Olav.',
             'Namsos Hospital': 'Namsos Hospital is a local hospital for 40,000 inhabitants in the northern part of Nord-Trøndelag. Centrally located in Namsos town, close to bus, boat and airport. The local hospital has functions in most fields with emergency departments, maternity wards, medical and surgical clinics and psychiatry.',
             'Levanger Hospital': 'Levanger Hospital has functions in most fields with emergency departments, maternity wards, paediatric wards, medical and surgical clinics and psychiatry. Local hospital for 100,000 inhabitants in the southern part of Nord-Trøndelag. Located downtown Levanger town, E6 and railway.',
             'Volda Hospital': 'Volda Hospital lay in Volda municipality in Søre Sunnmøre, 1.8 km from Volda town centre.',
             'Ålesund Hospital': 'Ålesund Heliport, Hospital (Norwegian: Ålesund helikopterplass, Sykehuset) is a heliport situated on the premises of Ålesund Hospital in Ålesund, Norway. Used exclusively for air ambulance services, it is home to an AgustaWestland AW139 operated by Lufttransport on contract with the Norwegian Air Ambulance.',
             'Molde Hospital': 'Serving a region of 120,000 residents, Molde Hospital, located on the west coast of Norway, performs 1.3 million tests per year on a range of different analyzers in its busy biochemistry department. Lab Manager, Arne Eide, was keen to improve how samples were managed after analysis and reduce the time spent looking for samples in cold storage.',
             'Kristiansund Hospital': 'Kristiansund is a municipality on the western coast of Norway in the Nordmøre district of Møre og Romsdal county. The administrative center of the municipality is the town of Kristiansund, which is the major town for the whole Nordmøre region.',
             'Elverum Hospital': 'Elverum Hospital (Norwegian: Elverum sykehus) is a general hospital situated in Elverum, Norway. It is part of Innlandet Hospital Trust, part of the Southern and Eastern Norway Regional Health Authority.'})
Front_Desk = pd.Series({'Aker University Hospital': 22894000,
             'Rikshospitalet': 23070000,
             'Ullevål University Hospital': 91502770,
             'Bærum Hospital': 67809400,
             'Kirkenes Hospital': 78967000,
             'Hammerfest Hospital': 75573000,
             'Røros Hospital': 74573000,
             'Orkdal Hospital': 73573000,
             'St. Olavs University Hospital': 72573000,
             'Namsos Hospital': 75098000,
             'Levanger Hospital': 74098000,
             'Volda Hospital': 72105000,
             'Ålesund Hospital': 71105000,
             'Molde Hospital': 70105000,
             'Kristiansund Hospital': 71120000,
             'Elverum Hospital': 91506200})

#Generated a Dataframe from the Series above

Hospitals = pd.DataFrame({'Major Location': Major_Location, 'Main Campus': Main_Campus, 'Description': Description, 'Front Desk Number': Front_Desk})

#print(Hospitals)

Hospitals
# Out:
#                               Major Location                     Main Campus  \
# Aker University Hospital                OSLO        Oslo University Hospital
# Rikshospitalet                          OSLO        Oslo University Hospital
# Ullevål University Hospital             OSLO        Oslo University Hospital
# Bærum Hospital                         BÆRUM           Vestre Viken Hospital
# Kirkenes Hospital                   KIRKENES          Finmark Hospital Trust
# Hammerfest Hospital               HAMMERFEST          Finmark Hospital Trust
# Røros Hospital                         RÆROS        St. Olavs Hospital Trust
# Orkdal Hospital                     ORKANGER        St. Olavs Hospital Trust
# St. Olavs University Hospital      TRONDHEIM        St. Olavs Hospital Trust
# Namsos Hospital                       NAMSOS   Nord-Trøndelag Hospital Trust
# Levanger Hospital                   LEVANGER   Nord-Trøndelag Hospital Trust
# ...

# %%
# Generated a new Column, based on Regional Health Authority cooresponding value to each hospital.

Regional_Health_Authority = pd.Series({'Aker University Hospital': 'Southern and Eastern Norway Regional Health Authority',
                                       'Elverum Hospital': 'Southern and Eastern Norway Regional Health Authority',
                                        'Rikshospitalet': 'Southern and Eastern Norway Regional Health Authority',
                                         'Ullevål University Hospital': 'Southern and Eastern Norway Regional Health Authority',
                                         'Bærum Hospital': 'Southern and Eastern Norway Regional Health Authority',
                                         'Kirkenes Hospital': 'Central Norway Regional Health Authority',
                                         'Hammerfest Hospital': 'Central Norway Regional Health Authority',
                                         'Røros Hospital': 'Central Norway Regional Health Authority',
                                         'Orkdal Hospital': 'Central Norway Regional Health Authority',
                                         'St. Olavs University Hospital': 'Central Norway Regional Health Authority',
                                         'Namsos Hospital': 'Central Norway Regional Health Authority',
                                         'Levanger Hospital': 'Central Norway Regional Health Authority',
                                         'Volda Hospital': 'Central Norway Regional Health Authority',
                                         'Ålesund Hospital': 'Central Norway Regional Health Authority',
                                         'Molde Hospital': 'Central Norway Regional Health Authority',
                                         'Kristiansund Hospital': 'Central Norway Regional Health Authority'})

Hospitals['Regional Health Authority'] = Regional_Health_Authority

Hospitals
# Out:
#                               Major Location                     Main Campus  \
# Aker University Hospital                OSLO        Oslo University Hospital
# Rikshospitalet                          OSLO        Oslo University Hospital
# Ullevål University Hospital             OSLO        Oslo University Hospital
# Bærum Hospital                         BÆRUM           Vestre Viken Hospital
# Kirkenes Hospital                   KIRKENES          Finmark Hospital Trust
# Hammerfest Hospital               HAMMERFEST          Finmark Hospital Trust
# Røros Hospital                         RÆROS        St. Olavs Hospital Trust
# Orkdal Hospital                     ORKANGER        St. Olavs Hospital Trust
# St. Olavs University Hospital      TRONDHEIM        St. Olavs Hospital Trust
# Namsos Hospital                       NAMSOS   Nord-Trøndelag Hospital Trust
# Levanger Hospital                   LEVANGER   Nord-Trøndelag Hospital Trust
# ...

# %% [markdown]
# Has the the pandemic affected the birth rate around the spesific Major Location?

# %%
import pandas as pd
import numpy as np

# Created a Series of the birth rate in the years: 2009, 2010, 2014, 2015, 2019 and 2020 from the url:https://www.ssb.no/statbank/list/fodte.
#Including Null values to the Location that didn't have a birth rate value.

Birth_2009 = pd.Series({'Aker University Hospital': 10254,
                                       'Elverum Hospital': 220,
                                        'Rikshospitalet': 10254,
                                         'Ullevål University Hospital': 10254,
                                         'Bærum Hospital': 1374,
                                         'Kirkenes Hospital': np.nan,
                                         'Hammerfest Hospital': 175,
                                         'Røros Hospital': 58,
                                         'Orkdal Hospital': np.nan,
                                         'St. Olavs University Hospital': 2570,
                                         'Namsos Hospital': 174,
                                         'Levanger Hospital': 222,
                                         'Volda Hospital': 116,
                                         'Ålesund Hospital': 805,
                                         'Molde Hospital': 343,
                                         'Kristiansund Hospital': 282})
Birth_2010 = pd.Series({'Aker University Hospital': 10267,
                                       'Elverum Hospital': 205,
                                        'Rikshospitalet': 10267,
                                         'Ullevål University Hospital': 10267,
                                         'Bærum Hospital': 1311,
                                         'Kirkenes Hospital': np.nan,
                                         'Hammerfest Hospital': 152,
                                         'Røros Hospital': 58,
                                         'Orkdal Hospital': np.nan,
                                         'St. Olavs University Hospital': 2579,
                                         'Namsos Hospital': 180,
                                         'Levanger Hospital': 219,
                                         'Volda Hospital': 105,
                                         'Ålesund Hospital': 717,
                                         'Molde Hospital': 319,
                                         'Kristiansund Hospital': 258})
Birth_2014 = pd.Series({'Aker University Hospital': 10154,
                                       'Elverum Hospital': 207,
                                        'Rikshospitalet': 10154,
                                         'Ullevål University Hospital': 10154,
                                         'Bærum Hospital': 1285,
                                         'Kirkenes Hospital': np.nan,
                                         'Hammerfest Hospital': 133,
                                         'Røros Hospital': 35,
                                         'Orkdal Hospital': np.nan,
                                         'St. Olavs University Hospital': 2422,
                                         'Namsos Hospital': 174,
                                         'Levanger Hospital': 202,
                                         'Volda Hospital': 80,
                                         'Ålesund Hospital': 696,
                                         'Molde Hospital': 335,
                                         'Kristiansund Hospital': 239})

Birth_2015 = pd.Series({'Aker University Hospital': 9899,
                                       'Elverum Hospital': 220,
                                        'Rikshospitalet': 9899,
                                         'Ullevål University Hospital': 9899,
                                         'Bærum Hospital': 1384,
                                         'Kirkenes Hospital': np.nan,
                                         'Hammerfest Hospital': 152,
                                         'Røros Hospital': 39,
                                         'Orkdal Hospital': np.nan,
                                         'St. Olavs University Hospital': 2380,
                                         'Namsos Hospital': 169,
                                         'Levanger Hospital': 240,
                                         'Volda Hospital': 95,
                                         'Ålesund Hospital': 805,
                                         'Molde Hospital': 359,
                                         'Kristiansund Hospital': 246})

Birth_2019 = pd.Series({'Aker University Hospital': 9343,
                                       'Elverum Hospital': 174,
                                        'Rikshospitalet': 9343,
                                         'Ullevål University Hospital': 9343,
                                         'Bærum Hospital': 1268,
                                         'Kirkenes Hospital': np.nan,
                                         'Hammerfest Hospital': 120,
                                         'Røros Hospital': 44,
                                         'Orkdal Hospital': np.nan,
                                         'St. Olavs University Hospital': 2291,
                                         'Namsos Hospital': 131,
                                         'Levanger Hospital': 221,
                                         'Volda Hospital': 105,
                                         'Ålesund Hospital': 640,
                                         'Molde Hospital': 328,
                                         'Kristiansund Hospital': 210})

Birth_2020 = pd.Series({'Aker University Hospital': 9199,
                                       'Elverum Hospital': 191,
                                        'Rikshospitalet': 9199,
                                         'Ullevål University Hospital': 9199,
                                         'Bærum Hospital': 1266,
                                         'Kirkenes Hospital': np.nan,
                                         'Hammerfest Hospital': 102,
                                         'Røros Hospital': 43,
                                         'Orkdal Hospital': np.nan,
                                         'St. Olavs University Hospital': 2115,
                                         'Namsos Hospital': 120,
                                         'Levanger Hospital': 204,
                                         'Volda Hospital': 104,
                                         'Ålesund Hospital': 657,
                                         'Molde Hospital': 314,
                                         'Kristiansund Hospital': 186})

#Created a DataFrame for each year

Birth_Rate = pd.DataFrame({'2009': Birth_2009, '2010': Birth_2010, '2014': Birth_2014, '2015': Birth_2015, '2019': Birth_2019, '2020': Birth_2020})

#Generated a new column to the 'Hospital' DataFrame

Hospitals['B.R: 2009'] = Birth_2009
Hospitals['B.R: 2010'] = Birth_2010
Hospitals['B.R: 2014'] = Birth_2014
Hospitals['B.R: 2015'] = Birth_2015
Hospitals['B.R: 2019'] = Birth_2019
Hospitals['B.R: 2020'] = Birth_2020

Hospitals
# Out:
#                               Major Location                     Main Campus  \
# Aker University Hospital                OSLO        Oslo University Hospital
# Rikshospitalet                          OSLO        Oslo University Hospital
# Ullevål University Hospital             OSLO        Oslo University Hospital
# Bærum Hospital                         BÆRUM           Vestre Viken Hospital
# Kirkenes Hospital                   KIRKENES          Finmark Hospital Trust
# Hammerfest Hospital               HAMMERFEST          Finmark Hospital Trust
# Røros Hospital                         RÆROS        St. Olavs Hospital Trust
# Orkdal Hospital                     ORKANGER        St. Olavs Hospital Trust
# St. Olavs University Hospital      TRONDHEIM        St. Olavs Hospital Trust
# Namsos Hospital                       NAMSOS   Nord-Trøndelag Hospital Trust
# Levanger Hospital                   LEVANGER   Nord-Trøndelag Hospital Trust
# ...

# %%
# Excluding Null values

Hospitals_d = Hospitals.dropna(axis = 0)

#Dropping columns that is not required to the vizualition

cleaned = Hospitals_d.drop(['Main Campus', 'Description', 'Front Desk Number', 'Regional Health Authority'], axis=1)
#Cleaning the DataFrame for any duplicates in thecolumn: 'Major Location'
Hospitals = cleaned.drop_duplicates('Major Location')
Hospitals
# Out:
#                               Major Location  B.R: 2009  B.R: 2010  B.R: 2014  \
# Aker University Hospital                OSLO    10254.0    10267.0    10154.0
# Bærum Hospital                         BÆRUM     1374.0     1311.0     1285.0
# Hammerfest Hospital               HAMMERFEST      175.0      152.0      133.0
# Røros Hospital                         RÆROS       58.0       58.0       35.0
# St. Olavs University Hospital      TRONDHEIM     2570.0     2579.0     2422.0
# Namsos Hospital                       NAMSOS      174.0      180.0      174.0
# Levanger Hospital                   LEVANGER      222.0      219.0      202.0
# Volda Hospital                         VOLDA      116.0      105.0       80.0
# Ålesund Hospital                     ÅLESUND      805.0      717.0      696.0
# Molde Hospital                         MOLDE      343.0      319.0      335.0
# Kristiansund Hospital           KRISTIANSUND      282.0      258.0      239.0
# ...

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')

#Vizualizing the birth rate from year: 2019 & 2020

H1 = Hospitals['B.R: 2020']
H2 = Hospitals['B.R: 2019']

plt.plot(H1, ydata, '.--r')
plt.plot(H2, ydata, '.b')

plt.title('Birth Rate in Major Locations')
plt.xlabel("Births")
plt.ylabel("Major/Birth Locations");

# Calculating the average of the years

H3 = Hospitals['B.R: 2020'] + Hospitals['B.R: 2019']
mean_H1 = H3.mean()




print(H3)
print('The 2014-2015 birth rate average:', mean_H1)
# Out:
# Aker University Hospital         18542.0
# Bærum Hospital                    2534.0
# Hammerfest Hospital                222.0
# Røros Hospital                      87.0
# St. Olavs University Hospital     4406.0
# Namsos Hospital                    251.0
# Levanger Hospital                  425.0
# Volda Hospital                     209.0
# Ålesund Hospital                  1297.0
# Molde Hospital                     642.0
# Kristiansund Hospital              396.0
# Elverum Hospital                   365.0
# dtype: float64
# The 2014-2015 birth rate average: 2448.0

# %%
#Vizualizing the birth rate from year: 2014 & 2015

H4 = Hospitals['B.R: 2015']
H5 = Hospitals['B.R: 2014']

plt.plot(H4, ydata, '.--r')
plt.plot(H5, ydata, '.y')

plt.title('Birth Rate in Major Locations')
plt.xlabel("Births")
plt.ylabel("Major/Birth Locations");

#Calculating the average of the years

H6 = Hospitals['B.R: 2015'] + Hospitals['B.R: 2014']
mean_H2 = H6.mean()



print(H6)
print('The 2014-2015 birth rate average:', mean_H2)
# Out:
# Aker University Hospital         20053.0
# Bærum Hospital                    2669.0
# Hammerfest Hospital                285.0
# Røros Hospital                      74.0
# St. Olavs University Hospital     4802.0
# Namsos Hospital                    343.0
# Levanger Hospital                  442.0
# Volda Hospital                     175.0
# Ålesund Hospital                  1501.0
# Molde Hospital                     694.0
# Kristiansund Hospital              485.0
# Elverum Hospital                   427.0
# dtype: float64
# The 2014-2015 birth rate average: 2662.5

# %%
#Vizualizing the birth rate from year: 2009 & 2010

H7 = Hospitals['B.R: 2010']
H8 = Hospitals['B.R: 2009']

plt.plot(H7, ydata, '.--r')
plt.plot(H8, ydata, '.g')

plt.title('Birth Rate in Major Locations')
plt.xlabel("Births")
plt.ylabel("Major/Birth Locations");

#Calculating the average of the years

H9 = Hospitals['B.R: 2010'] + Hospitals['B.R: 2009']
mean_H3 = H9.mean()

print(H9)
print('The 2014-2015 birth rate average:', mean_H3)
# Out:
# Aker University Hospital         20521.0
# Bærum Hospital                    2685.0
# Hammerfest Hospital                327.0
# Røros Hospital                     116.0
# St. Olavs University Hospital     5149.0
# Namsos Hospital                    354.0
# Levanger Hospital                  441.0
# Volda Hospital                     221.0
# Ålesund Hospital                  1522.0
# Molde Hospital                     662.0
# Kristiansund Hospital              540.0
# Elverum Hospital                   425.0
# dtype: float64
# The 2014-2015 birth rate average: 2746.9166666666665

# %%
# All the birth rates in one plot

plt.plot(H1, ydata, '.-b')
plt.plot(H2, ydata, '.-b')
plt.plot(H4, ydata, '.-r')
plt.plot(H5, ydata, '.-y')
plt.plot(H7, ydata, '.-r')
plt.plot(H8, ydata, '.-g')

# %%
# The average between the 14 Major Location 
print('The 2009-2010 birth rate average between the 14 Major Location :', mean_H3)
print('The 2014-2015 birth rate average between the 14 Major Location :', mean_H2) 
print('The 2019-2020 birth rate average between the 14 Major Location :', mean_H1)
# Out:
# The 2009-2010 birth rate average between the 14 Major Location : 2746.9166666666665
# The 2014-2015 birth rate average between the 14 Major Location : 2662.5
# The 2019-2020 birth rate average between the 14 Major Location : 2448.0

# %%
#Percentage Difference between the average calculation of the different years

diff_Hospitals1= (mean_H2-mean_H1)/mean_H2*100
diff_Hospitals2= (mean_H3-mean_H2)/mean_H3*100

print('Percentage Difference between 2019-20 & 2014-15:', diff_Hospitals1)
print('Percentage Difference between 2009-10 & 2014-15:', diff_Hospitals2)
# Out:
# Percentage Difference between 2019-20 & 2014-15: 8.056338028169014
# Percentage Difference between 2009-10 & 2014-15: 3.0731426144464953

# %% [markdown]
# # Conclusion
# As it is shown in the different line plots for each year we don't see a major difference, but what when we look at the procentage difference, we can claim is that the average birth rate between the Major locations down graded with in the past 5 year and 10 years. From 2014-15 to 2009-10  it had decreased with 8.05% but on the other hand from 2009-10 to 2014-15 it had decreased with 3.07%. That in a way shows that the pandemic might be some of the factors for the average birthrate between the different location had decreased but it also shows that the birth rate in Norway has generally had low birthrate because of other factores before the pandemic. This question can be featured improved.
